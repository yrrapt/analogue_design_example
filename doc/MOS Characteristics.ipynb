# %%
# %load_ext autoreload
# %autoreload 2

from yaaade.characterise.mos import QueryMos
import matplotlib.pyplot as plt

plt.rcParams['figure.figsize'] = [12, 8]
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
query_obj = {'nfet'     : QueryMos('data/sky130_fd_pr__nfet_01v8.hdf5'),
             'nfet_lvt' : QueryMos('data/sky130_fd_pr__nfet_01v8_lvt.hdf5'),
             'pfet'     : QueryMos('data/sky130_fd_pr__pfet_01v8.hdf5'),
             'pfet_lvt' : QueryMos('data/sky130_fd_pr__pfet_01v8_lvt.hdf5')}

# %% [markdown]
# ## Plot gm/Id

# %% [markdown]
# #### NMOS LVT

# %%
conditions = {  'l'     :   query_obj['nfet_lvt'].get_parameter_values('l'),
                'vbs'   :   0.00,
                'vds'   :   0.90}
query_obj['nfet_lvt'].plot(x='gm/id', y='id', conditions=conditions)

# %% [markdown]
# #### PMOS LVT

# %%
conditions = {  'l'     :   query_obj['pfet_lvt'].get_parameter_values('l'),
                'vbs'   :   0.00,
                'vds'   :   0.90}
query_obj['pfet_lvt'].plot(x='gm/id', y='id', conditions=conditions)

# %%
conditions = {  'l'     :   query_obj['pfet_lvt'].get_parameter_values('l'),
                'vbs'   :   0.00,
                'vds'   :   0.90}
query_obj['pfet_lvt'].plot(x='gm/id', y='gm/gds', conditions=conditions)
